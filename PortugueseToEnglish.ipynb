# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'por.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-por.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-por.pkl
# [go] => [vai]
# [go] => [va]
# [hi] => [oi]
# [run] => [corre]
# [run] => [corra]
# [run] => [corram]
# [run] => [corre]
# [run] => [corra]
# [run] => [corram]
# [who] => [quem]
# [who] => [que]
# [wow] => [uau]
# [wow] => [nossa]
# [wow] => [wow]
# [fire] => [fogo]
# [fire] => [incendio]
# [fire] => [chama]
# [help] => [ajuda]
# [help] => [socorro]
# [jump] => [pule]
# [jump] => [pula]
# [jump] => [pulem]
# [jump] => [pule]
# [jump] => [pulam]
# [stop] => [pare]
# [stop] => [parem]
# [stop] => [parada]
# [stop] => [ponto]
# [stop] => [para]
# [wait] => [espere]
# [wait] => [aguarde]
# [wait] => [espere]
# [wait] => [esperem]
# [go on] => [siga em frente]
# [go on] => [va]
# [go on] => [continue]
# [go on] => [siga adiante]
# [hello] => [oi]
# [hello] => [alo]
# [hello] => [ola]
# [hello] => [alo]
# [i ran] => [eu corri]
# [i see] => [eu sei]
# [i see] => [eu entendo]
# [i see] => [estou vendo]
# [i see] => [eu vejo]
# [i see] => [eu assisto]
# [i try] => [eu tento]
# [i try] => [tento]
# [i won] => [ganhei]
# [i won] => [eu venci]
# [oh no] => [ah nao]
# [relax] => [relaxe]
# [relax] => [relaxa]
# [relax] => [relaxe]
# [shoot] => [tiro]
# [smile] => [sorria]
# [smile] => [sorriam]
# [attack] => [atacar]
# [attack] => [ataquem]
# [attack] => [ataque]
# [cheers] => [saude]
# [freeze] => [parado]
# [get up] => [levantese]
# [get up] => [levantemse]
# [get up] => [levantate]
# [get up] => [levantese]
# [get up] => [levantate]
# [go now] => [va agora]
# [got it] => [entendi]
# [got it] => [eu entendi]
# [got it] => [saquei]
# [got it] => [entendeu]
# [he ran] => [ele correu]
# [he ran] => [ele corria]
# [hop in] => [sobe ai]
# [hop in] => [entra ai]
# [hug me] => [me abrace]
# [i fell] => [eu cai]
# [i knit] => [eu tricoto]
# [i know] => [eu sei]
# [i know] => [sei]
# [i left] => [eu sai]
# [i lied] => [eu menti]
# [i paid] => [eu paguei]
# [i quit] => [eu me demito]
# [i work] => [eu estou trabalhando]
# [im ok] => [estou bem]
# [im ok] => [eu vou bem]
# [im up] => [estou acordado]
# [listen] => [escute]
# [listen] => [oucame]
# [listen] => [escuta]
# [listen] => [escutem]
# [listen] => [ouca isso]
# [listen] => [escutemme]
# [listen] => [escute]
# [listen] => [escuta]
# [listen] => [escutem]
# [listen] => [escutai]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-por.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-por-both.pkl')
save_clean_data(train, 'english-por-train.pkl')
save_clean_data(test, 'english-por-test.pkl')
# Out:
# Saved: english-por-both.pkl
# Saved: english-por-train.pkl
# Saved: english-por-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-por-both.pkl')
train = load_clean_sentences('english-por-train.pkl')
test = load_clean_sentences('english-por-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Portuguese Vocabulary Size: %d' % ger_vocab_size)
print('Portuguese Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2092
# English Max Length: 5
# Portuguese Vocabulary Size: 3698
# Portuguese Max Length: 8
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 8, 256)            946688
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 5, 256)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 5, 2092)           537644
# =================================================================
# Total params: 2,534,956
# Trainable params: 2,534,956
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 35s - loss: 4.1465 - val_loss: 3.2846
#
# Epoch 00001: val_loss improved from inf to 3.28456, saving model to model.h5
# Epoch 2/100
# 141/141 - 28s - loss: 3.2017 - val_loss: 3.0951
#
# Epoch 00002: val_loss improved from 3.28456 to 3.09514, saving model to model.h5
# Epoch 3/100
# 141/141 - 28s - loss: 3.0617 - val_loss: 2.9749
#
# Epoch 00003: val_loss improved from 3.09514 to 2.97495, saving model to model.h5
# Epoch 4/100
# 141/141 - 27s - loss: 2.9526 - val_loss: 2.8816
#
# Epoch 00004: val_loss improved from 2.97495 to 2.88155, saving model to model.h5
# Epoch 5/100
# 141/141 - 27s - loss: 2.8364 - val_loss: 2.7436
#
# Epoch 00005: val_loss improved from 2.88155 to 2.74360, saving model to model.h5
# Epoch 6/100
# 141/141 - 28s - loss: 2.6987 - val_loss: 2.5941
#
# Epoch 00006: val_loss improved from 2.74360 to 2.59406, saving model to model.h5
# Epoch 7/100
# 141/141 - 28s - loss: 2.5285 - val_loss: 2.4277
#
# Epoch 00007: val_loss improved from 2.59406 to 2.42767, saving model to model.h5
# Epoch 8/100
# 141/141 - 27s - loss: 2.3694 - val_loss: 2.2667
#
# Epoch 00008: val_loss improved from 2.42767 to 2.26670, saving model to model.h5
# Epoch 9/100
# 141/141 - 28s - loss: 2.2103 - val_loss: 2.1170
#
# Epoch 00009: val_loss improved from 2.26670 to 2.11704, saving model to model.h5
# Epoch 10/100
# 141/141 - 28s - loss: 2.0674 - val_loss: 1.9869
#
# Epoch 00010: val_loss improved from 2.11704 to 1.98694, saving model to model.h5
# Epoch 11/100
# 141/141 - 29s - loss: 1.9366 - val_loss: 1.8673
#
# Epoch 00011: val_loss improved from 1.98694 to 1.86735, saving model to model.h5
# Epoch 12/100
# 141/141 - 28s - loss: 1.8122 - val_loss: 1.7503
#
# Epoch 00012: val_loss improved from 1.86735 to 1.75032, saving model to model.h5
# Epoch 13/100
# 141/141 - 28s - loss: 1.6980 - val_loss: 1.6406
#
# Epoch 00013: val_loss improved from 1.75032 to 1.64064, saving model to model.h5
# Epoch 14/100
# 141/141 - 28s - loss: 1.5852 - val_loss: 1.5317
#
# Epoch 00014: val_loss improved from 1.64064 to 1.53170, saving model to model.h5
# Epoch 15/100
# 141/141 - 28s - loss: 1.4800 - val_loss: 1.4370
#
# Epoch 00015: val_loss improved from 1.53170 to 1.43704, saving model to model.h5
# Epoch 16/100
# 141/141 - 27s - loss: 1.3777 - val_loss: 1.3407
#
# Epoch 00016: val_loss improved from 1.43704 to 1.34069, saving model to model.h5
# Epoch 17/100
# 141/141 - 28s - loss: 1.2805 - val_loss: 1.2492
#
# Epoch 00017: val_loss improved from 1.34069 to 1.24922, saving model to model.h5
# Epoch 18/100
# 141/141 - 27s - loss: 1.1859 - val_loss: 1.1718
#
# Epoch 00018: val_loss improved from 1.24922 to 1.17179, saving model to model.h5
# Epoch 19/100
# 141/141 - 27s - loss: 1.1027 - val_loss: 1.0914
#
# Epoch 00019: val_loss improved from 1.17179 to 1.09138, saving model to model.h5
# Epoch 20/100
# 141/141 - 28s - loss: 1.0178 - val_loss: 1.0128
#
# Epoch 00020: val_loss improved from 1.09138 to 1.01284, saving model to model.h5
# Epoch 21/100
# 141/141 - 28s - loss: 0.9376 - val_loss: 0.9391
#
# Epoch 00021: val_loss improved from 1.01284 to 0.93911, saving model to model.h5
# Epoch 22/100
# 141/141 - 28s - loss: 0.8667 - val_loss: 0.8759
#
# Epoch 00022: val_loss improved from 0.93911 to 0.87589, saving model to model.h5
# Epoch 23/100
# 141/141 - 27s - loss: 0.7941 - val_loss: 0.8180
#
# Epoch 00023: val_loss improved from 0.87589 to 0.81798, saving model to model.h5
# Epoch 24/100
# 141/141 - 27s - loss: 0.7358 - val_loss: 0.7649
#
# Epoch 00024: val_loss improved from 0.81798 to 0.76489, saving model to model.h5
# Epoch 25/100
# 141/141 - 27s - loss: 0.6730 - val_loss: 0.7111
#
# Epoch 00025: val_loss improved from 0.76489 to 0.71114, saving model to model.h5
# Epoch 26/100
# 141/141 - 27s - loss: 0.6153 - val_loss: 0.6662
#
# Epoch 00026: val_loss improved from 0.71114 to 0.66619, saving model to model.h5
# Epoch 27/100
# 141/141 - 27s - loss: 0.5675 - val_loss: 0.6249
#
# Epoch 00027: val_loss improved from 0.66619 to 0.62491, saving model to model.h5
# Epoch 28/100
# 141/141 - 28s - loss: 0.5212 - val_loss: 0.5848
#
# Epoch 00028: val_loss improved from 0.62491 to 0.58477, saving model to model.h5
# Epoch 29/100
# 141/141 - 28s - loss: 0.4788 - val_loss: 0.5536
#
# Epoch 00029: val_loss improved from 0.58477 to 0.55356, saving model to model.h5
# Epoch 30/100
# 141/141 - 28s - loss: 0.4431 - val_loss: 0.5233
#
# Epoch 00030: val_loss improved from 0.55356 to 0.52329, saving model to model.h5
# Epoch 31/100
# 141/141 - 28s - loss: 0.4093 - val_loss: 0.4961
#
# Epoch 00031: val_loss improved from 0.52329 to 0.49605, saving model to model.h5
# Epoch 32/100
# 141/141 - 28s - loss: 0.3780 - val_loss: 0.4691
#
# Epoch 00032: val_loss improved from 0.49605 to 0.46906, saving model to model.h5
# Epoch 33/100
# 141/141 - 28s - loss: 0.3510 - val_loss: 0.4530
#
# Epoch 00033: val_loss improved from 0.46906 to 0.45299, saving model to model.h5
# Epoch 34/100
# 141/141 - 28s - loss: 0.3262 - val_loss: 0.4319
#
# Epoch 00034: val_loss improved from 0.45299 to 0.43188, saving model to model.h5
# Epoch 35/100
# 141/141 - 27s - loss: 0.3039 - val_loss: 0.4132
#
# Epoch 00035: val_loss improved from 0.43188 to 0.41320, saving model to model.h5
# Epoch 36/100
# 141/141 - 27s - loss: 0.2847 - val_loss: 0.4035
#
# Epoch 00036: val_loss improved from 0.41320 to 0.40353, saving model to model.h5
# Epoch 37/100
# 141/141 - 27s - loss: 0.2669 - val_loss: 0.3861
#
# Epoch 00037: val_loss improved from 0.40353 to 0.38612, saving model to model.h5
# Epoch 38/100
# 141/141 - 27s - loss: 0.2507 - val_loss: 0.3750
#
# Epoch 00038: val_loss improved from 0.38612 to 0.37499, saving model to model.h5
# Epoch 39/100
# 141/141 - 27s - loss: 0.2359 - val_loss: 0.3639
#
# Epoch 00039: val_loss improved from 0.37499 to 0.36393, saving model to model.h5
# Epoch 40/100
# 141/141 - 28s - loss: 0.2234 - val_loss: 0.3612
#
# Epoch 00040: val_loss improved from 0.36393 to 0.36119, saving model to model.h5
# Epoch 41/100
# 141/141 - 28s - loss: 0.2135 - val_loss: 0.3452
#
# Epoch 00041: val_loss improved from 0.36119 to 0.34524, saving model to model.h5
# Epoch 42/100
# 141/141 - 28s - loss: 0.2018 - val_loss: 0.3374
#
# Epoch 00042: val_loss improved from 0.34524 to 0.33741, saving model to model.h5
# Epoch 43/100
# 141/141 - 29s - loss: 0.1936 - val_loss: 0.3347
#
# Epoch 00043: val_loss improved from 0.33741 to 0.33470, saving model to model.h5
# Epoch 44/100
# 141/141 - 28s - loss: 0.1853 - val_loss: 0.3263
#
# Epoch 00044: val_loss improved from 0.33470 to 0.32631, saving model to model.h5
# Epoch 45/100
# 141/141 - 29s - loss: 0.1776 - val_loss: 0.3216
#
# Epoch 00045: val_loss improved from 0.32631 to 0.32163, saving model to model.h5
# Epoch 46/100
# 141/141 - 28s - loss: 0.1720 - val_loss: 0.3201
#
# Epoch 00046: val_loss improved from 0.32163 to 0.32014, saving model to model.h5
# Epoch 47/100
# 141/141 - 28s - loss: 0.1655 - val_loss: 0.3132
#
# Epoch 00047: val_loss improved from 0.32014 to 0.31318, saving model to model.h5
# Epoch 48/100
# 141/141 - 28s - loss: 0.1602 - val_loss: 0.3100
#
# Epoch 00048: val_loss improved from 0.31318 to 0.31001, saving model to model.h5
# Epoch 49/100
# 141/141 - 28s - loss: 0.1566 - val_loss: 0.3046
#
# Epoch 00049: val_loss improved from 0.31001 to 0.30465, saving model to model.h5
# Epoch 50/100
# 141/141 - 28s - loss: 0.1508 - val_loss: 0.3054
#
# Epoch 00050: val_loss did not improve from 0.30465
# Epoch 51/100
# 141/141 - 28s - loss: 0.1466 - val_loss: 0.3006
#
# Epoch 00051: val_loss improved from 0.30465 to 0.30055, saving model to model.h5
# Epoch 52/100
# 141/141 - 28s - loss: 0.1428 - val_loss: 0.2979
#
# Epoch 00052: val_loss improved from 0.30055 to 0.29787, saving model to model.h5
# Epoch 53/100
# 141/141 - 27s - loss: 0.1402 - val_loss: 0.2956
#
# Epoch 00053: val_loss improved from 0.29787 to 0.29561, saving model to model.h5
# Epoch 54/100
# 141/141 - 28s - loss: 0.1365 - val_loss: 0.2948
#
# Epoch 00054: val_loss improved from 0.29561 to 0.29478, saving model to model.h5
# Epoch 55/100
# 141/141 - 27s - loss: 0.1339 - val_loss: 0.2946
#
# Epoch 00055: val_loss improved from 0.29478 to 0.29465, saving model to model.h5
# Epoch 56/100
# 141/141 - 28s - loss: 0.1323 - val_loss: 0.2943
#
# Epoch 00056: val_loss improved from 0.29465 to 0.29425, saving model to model.h5
# Epoch 57/100
# 141/141 - 28s - loss: 0.1298 - val_loss: 0.2914
#
# Epoch 00057: val_loss improved from 0.29425 to 0.29142, saving model to model.h5
# Epoch 58/100
# 141/141 - 28s - loss: 0.1277 - val_loss: 0.2922
#
# Epoch 00058: val_loss did not improve from 0.29142
# Epoch 59/100
# 141/141 - 27s - loss: 0.1260 - val_loss: 0.2915
#
# Epoch 00059: val_loss did not improve from 0.29142
# Epoch 60/100
# 141/141 - 27s - loss: 0.1234 - val_loss: 0.2882
#
# Epoch 00060: val_loss improved from 0.29142 to 0.28823, saving model to model.h5
# Epoch 61/100
# 141/141 - 27s - loss: 0.1209 - val_loss: 0.2864
#
# Epoch 00061: val_loss improved from 0.28823 to 0.28640, saving model to model.h5
# Epoch 62/100
# 141/141 - 28s - loss: 0.1183 - val_loss: 0.2866
#
# Epoch 00062: val_loss did not improve from 0.28640
# Epoch 63/100
# 141/141 - 27s - loss: 0.1182 - val_loss: 0.2845
#
# Epoch 00063: val_loss improved from 0.28640 to 0.28454, saving model to model.h5
# Epoch 64/100
# 141/141 - 28s - loss: 0.1159 - val_loss: 0.2877
#
# Epoch 00064: val_loss did not improve from 0.28454
# Epoch 65/100
# 141/141 - 28s - loss: 0.1157 - val_loss: 0.2851
#
# Epoch 00065: val_loss did not improve from 0.28454
# Epoch 66/100
# 141/141 - 27s - loss: 0.1153 - val_loss: 0.2864
#
# Epoch 00066: val_loss did not improve from 0.28454
# Epoch 67/100
# 141/141 - 28s - loss: 0.1152 - val_loss: 0.2852
#
# Epoch 00067: val_loss did not improve from 0.28454
# Epoch 68/100
# 141/141 - 28s - loss: 0.1122 - val_loss: 0.2827
#
# Epoch 00068: val_loss improved from 0.28454 to 0.28266, saving model to model.h5
# Epoch 69/100
# 141/141 - 27s - loss: 0.1105 - val_loss: 0.2840
#
# Epoch 00069: val_loss did not improve from 0.28266
# Epoch 70/100
# 141/141 - 27s - loss: 0.1103 - val_loss: 0.2869
#
# Epoch 00070: val_loss did not improve from 0.28266
# Epoch 71/100
# 141/141 - 27s - loss: 0.1099 - val_loss: 0.2854
#
# Epoch 00071: val_loss did not improve from 0.28266
# Epoch 72/100
# 141/141 - 27s - loss: 0.1098 - val_loss: 0.2830
#
# Epoch 00072: val_loss did not improve from 0.28266
# Epoch 73/100
# 141/141 - 27s - loss: 0.1091 - val_loss: 0.2835
#
# Epoch 00073: val_loss did not improve from 0.28266
# Epoch 74/100
# 141/141 - 27s - loss: 0.1070 - val_loss: 0.2840
#
# Epoch 00074: val_loss did not improve from 0.28266
# Epoch 75/100
# 141/141 - 27s - loss: 0.1066 - val_loss: 0.2836
#
# Epoch 00075: val_loss did not improve from 0.28266
# Epoch 76/100
# 141/141 - 28s - loss: 0.1052 - val_loss: 0.2833
#
# Epoch 00076: val_loss did not improve from 0.28266
# Epoch 77/100
# 141/141 - 27s - loss: 0.1042 - val_loss: 0.2845
#
# Epoch 00077: val_loss did not improve from 0.28266
# Epoch 78/100
# 141/141 - 27s - loss: 0.1044 - val_loss: 0.2838
#
# Epoch 00078: val_loss did not improve from 0.28266
# Epoch 79/100
# 141/141 - 28s - loss: 0.1038 - val_loss: 0.2841
#
# Epoch 00079: val_loss did not improve from 0.28266
# Epoch 80/100
# 141/141 - 28s - loss: 0.1029 - val_loss: 0.2830
#
# Epoch 00080: val_loss did not improve from 0.28266
# Epoch 81/100
# 141/141 - 27s - loss: 0.1017 - val_loss: 0.2820
#
# Epoch 00081: val_loss improved from 0.28266 to 0.28200, saving model to model.h5
# Epoch 82/100
# 141/141 - 27s - loss: 0.1013 - val_loss: 0.2821
#
# Epoch 00082: val_loss did not improve from 0.28200
# Epoch 83/100
# 141/141 - 27s - loss: 0.1010 - val_loss: 0.2827
#
# Epoch 00083: val_loss did not improve from 0.28200
# Epoch 84/100
# 141/141 - 28s - loss: 0.1010 - val_loss: 0.2812
#
# Epoch 00084: val_loss improved from 0.28200 to 0.28121, saving model to model.h5
# Epoch 85/100
# 141/141 - 27s - loss: 0.1012 - val_loss: 0.2824
#
# Epoch 00085: val_loss did not improve from 0.28121
# Epoch 86/100
# 141/141 - 27s - loss: 0.1017 - val_loss: 0.2879
#
# Epoch 00086: val_loss did not improve from 0.28121
# Epoch 87/100
# 141/141 - 28s - loss: 0.1032 - val_loss: 0.2911
#
# Epoch 00087: val_loss did not improve from 0.28121
# Epoch 88/100
# 141/141 - 27s - loss: 0.1038 - val_loss: 0.2855
#
# Epoch 00088: val_loss did not improve from 0.28121
# Epoch 89/100
# 141/141 - 28s - loss: 0.1021 - val_loss: 0.2858
#
# Epoch 00089: val_loss did not improve from 0.28121
# Epoch 90/100
# 141/141 - 28s - loss: 0.1009 - val_loss: 0.2847
#
# Epoch 00090: val_loss did not improve from 0.28121
# Epoch 91/100
# 141/141 - 28s - loss: 0.1005 - val_loss: 0.2863
#
# Epoch 00091: val_loss did not improve from 0.28121
# Epoch 92/100
# 141/141 - 27s - loss: 0.0985 - val_loss: 0.2836
#
# Epoch 00092: val_loss did not improve from 0.28121
# Epoch 93/100
# 141/141 - 27s - loss: 0.0975 - val_loss: 0.2841
#
# Epoch 00093: val_loss did not improve from 0.28121
# Epoch 94/100
# 141/141 - 27s - loss: 0.0966 - val_loss: 0.2842
#
# Epoch 00094: val_loss did not improve from 0.28121
# Epoch 95/100
# 141/141 - 27s - loss: 0.0967 - val_loss: 0.2836
#
# Epoch 00095: val_loss did not improve from 0.28121
# Epoch 96/100
# 141/141 - 28s - loss: 0.0957 - val_loss: 0.2844
#
# Epoch 00096: val_loss did not improve from 0.28121
# Epoch 97/100
# 141/141 - 27s - loss: 0.0960 - val_loss: 0.2846
#
# Epoch 00097: val_loss did not improve from 0.28121
# Epoch 98/100
# 141/141 - 27s - loss: 0.0948 - val_loss: 0.2864
#
# Epoch 00098: val_loss did not improve from 0.28121
# Epoch 99/100
# 141/141 - 28s - loss: 0.0949 - val_loss: 0.2850
#
# Epoch 00099: val_loss did not improve from 0.28121
# Epoch 100/100
# 141/141 - 27s - loss: 0.0946 - val_loss: 0.2862
#
# Epoch 00100: val_loss did not improve from 0.28121

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-por-both.pkl')
train = load_clean_sentences('english-por-train.pkl')
test = load_clean_sentences('english-por-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[tom e destemido], target=[toms fearless], predicted=[toms fearless]
# src=[eu posso correr], target=[i can run], predicted=[i can run]
# src=[somos especiais], target=[were special], predicted=[were special]
# src=[corre e escondete], target=[run and hide], predicted=[run and hide]
# src=[quem esta aqui], target=[whos here], predicted=[whos here]
# src=[tom arfou], target=[tom gasped], predicted=[tom gasped]
# src=[eu estava me escondendo], target=[i was hiding], predicted=[i was hiding]
# src=[traga reforcos], target=[bring backup], predicted=[bring backup]
# src=[eu estou livre agora], target=[im free now], predicted=[im free now]
# src=[e adoravel], target=[its adorable], predicted=[its adorable]
# BLEU-1: 0.939653
# BLEU-2: 0.916197
# BLEU-3: 0.824953
# BLEU-4: 0.501022
# test
# src=[abracem o tom], target=[hug tom], predicted=[hug tom]
# src=[tom nao tem certeza], target=[tom isnt sure], predicted=[tom isnt unsure]
# src=[estamos brincando], target=[were joking], predicted=[were joking]
# src=[tom esta com ciumes], target=[toms jealous], predicted=[toms jealous jealous]
# src=[essa e minha], target=[is this mine], predicted=[is this]
# src=[ei relaxa], target=[hey relax], predicted=[hey relax]
# src=[estas tolo], target=[are you mad], predicted=[are you mad]
# src=[ele mente], target=[hes a liar], predicted=[hes lying liar]
# src=[nos te amamos], target=[we love you], predicted=[we love you]
# src=[nos vamos precisar disso], target=[well need it], predicted=[well need it]
# BLEU-1: 0.905399
# BLEU-2: 0.874371
# BLEU-3: 0.785810
# BLEU-4: 0.471336

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,train = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-por-both.pkl')
train = load_clean_sentences('english-por-train.pkl')
test = load_clean_sentences('english-por-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[tom e destemido], target=[toms fearless], predicted=[toms fearless]
# src=[eu posso correr], target=[i can run], predicted=[i can run]
# src=[somos especiais], target=[were special], predicted=[were special]
# src=[corre e escondete], target=[run and hide], predicted=[run and hide]
# src=[quem esta aqui], target=[whos here], predicted=[whos here]
# src=[tom arfou], target=[tom gasped], predicted=[tom gasped]
# src=[eu estava me escondendo], target=[i was hiding], predicted=[i was hiding]
# src=[traga reforcos], target=[bring backup], predicted=[bring backup]
# src=[eu estou livre agora], target=[im free now], predicted=[im free now]
# src=[e adoravel], target=[its adorable], predicted=[its adorable]
# BLEU-1: 0.939653
# BLEU-2: 0.916197
# BLEU-3: 0.824953
# BLEU-4: 0.501022
# test
# src=[abracem o tom], target=[hug tom], predicted=[hug tom]
# src=[tom nao tem certeza], target=[tom isnt sure], predicted=[tom isnt unsure]
# src=[estamos brincando], target=[were joking], predicted=[were joking]
# src=[tom esta com ciumes], target=[toms jealous], predicted=[toms jealous jealous]
# src=[essa e minha], target=[is this mine], predicted=[is this]
# src=[ei relaxa], target=[hey relax], predicted=[hey relax]
# src=[estas tolo], target=[are you mad], predicted=[are you mad]
# src=[ele mente], target=[hes a liar], predicted=[hes lying liar]
# src=[nos te amamos], target=[we love you], predicted=[we love you]
# src=[nos vamos precisar disso], target=[well need it], predicted=[well need it]
# BLEU-1: 0.905399
# BLEU-2: 0.874371
# BLEU-3: 0.785810
# BLEU-4: 0.471336
